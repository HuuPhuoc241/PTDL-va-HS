# %%
import pandas as pd
import numpy as np

# %%
# Vấn đề 1
# Thêm header vào dataframe để diễn giải dữ liệu
column_names= ["Id", "Name", "Age", "Weight", 'm0006', 'm0612', 'm1218', 'f0006', 'f0612', 'f1218']
# Đọc file dữ liệu
df = pd.read_csv("heart_disease_dataset.csv", names = column_names)
# Hiển thị một vài dòng dữ liệu đầu tiên ra màn màn hình
print(df.head())
# Out:
#                         Id Name      Age   Weight  m0006    m0612  m1218  \
# age sex cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope
# 63  M   tap 145        233  yes        2      150      0      2.3      3
# 67  M   asp 160        286   no        2      108      1      1.5      2
#             120        229   no        2      129      1      2.6      2
# 37  M   nap 130        250   no        0      187      0      3.5      3
#
#                      f0006 f0612  f1218
# age sex cp  trestbps    ca  thal  state
# 63  M   tap 145          0     6      0
# 67  M   asp 160          3     3      2
#             120          2     7      1
# 37  M   nap 130          0     3      0

# %%
# Vấn đề 2
# Xử lý lỗi: Các giá trị trong cột 'Name' không phải lúc nào cũng có 2 phần để tách.
# Ta sẽ tách tối đa 1 lần (n=1) và điền rỗng cho phần 'Lastname' nếu không có.
split_names = df['Name'].astype(str).str.split(n=1, expand=True)

df['Firstname'] = split_names[0]
# Gán 'Lastname' là phần thứ hai nếu có, nếu không thì là chuỗi rỗng
df['Lastname'] = split_names[1].fillna('') if split_names.shape[1] > 1 else ''

df = df.drop('Name', axis=1)
print (df)
# Out:
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]

# %%
# Vấn đề 3
# Get the Weight column
weight = df['Weight']

for i in range (0, len(weight)):
  x = str(weight[i])
  # Incase lbs is part of observation remove it
  if "lbs" in x[-3:]:
    # Remove the lbs from the value
    x = x[:-3:]
    # Convert string to float
    float_x = float(x)
    # Convert to kgs and store as int
    y =int (float_x/2.2)
    # Convert back to string
    y = str(y)+"kgs"
    weight[i]= y
  print (df)
# Out:
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])
# /tmp/ipykernel_538/1129931759.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x = str(weight[i])

# %%
# Vấn đề 4
df.dropna(how="all", inplace=True)
print (df)
# Out:
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 45  M   tap 110        264        0      132      0      1.2      2     0
# 68  M   asp 144        193        0      141      0      3.4      2     2
# NaN NaN NaN NaN        NaN      NaN      NaN    NaN      NaN    NaN   NaN
# 57  F   aap 130        236        2      174      0        0      2     1
# 38  M   nap 138        175        0      173      0        0      1   NaN
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 45  M   tap 110          7      1        no
# 68  M   asp 144          7      2       yes
# NaN NaN NaN NaN        NaN    NaN       nan
# 57  F   aap 130          3      1        no
# 38  M   nap 138          3      0        no
#
# [304 rows x 11 columns]

# %%
# Vấn đề 5
df = df.drop_duplicates(subset=['Firstname', 'Lastname', 'Age', 'Weight'])
print(df)
# Out:
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 67  M   nap 152        212        2      NaN      0      0.8      2     0
# 55  F   aap 132        342        0      166      0      1.2      1     0
# 63  F   asp 124        197        0      136      1        0      2     0
# 59  M   asp 164        176        2       90      0        1      2     2
# 68  M   asp 144        193        0      141      0      3.4      2     2
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 67  M   nap 152          7      1        no
# 55  F   aap 132          3      0        no
# 63  F   asp 124          3      1        no
# 59  M   asp 164          6      3       yes
# 68  M   asp 144          7      2       yes
#
# [176 rows x 11 columns]

# %%
# Vấn đề 6
df.Firstname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
df.Lastname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
print(df)
# Out:
#                         Id      Age   Weight  m0006    m0612  m1218 f0006  \
# age sex cp  trestbps  chol  restecg  thalach  exang  oldpeak  slope    ca
# 63  M   tap 145        233        2      150      0      2.3      3     0
# 67  M   asp 160        286        2      108      1      1.5      2     3
#             120        229        2      129      1      2.6      2     2
# 37  M   nap 130        250        0      187      0      3.5      3     0
# ...                    ...      ...      ...    ...      ...    ...   ...
# 67  M   nap 152        212        2      NaN      0      0.8      2     0
# 55  F   aap 132        342        0      166      0      1.2      1     0
# 63  F   asp 124        197        0      136      1        0      2     0
# 59  M   asp 164        176        2       90      0        1      2     2
# 68  M   asp 144        193        0      141      0      3.4      2     2
#
#                      f0612  f1218 Firstname Lastname
# age sex cp  trestbps  thal  state       fbs
# 63  M   tap 145          6      0       yes
# 67  M   asp 160          3      2        no
#             120          7      1        no
# 37  M   nap 130          3      0        no
# ...                    ...    ...       ...      ...
# 67  M   nap 152          7      1        no
# 55  F   aap 132          3      0        no
# 63  F   asp 124          3      1        no
# 59  M   asp 164          6      3       yes
# 68  M   asp 144          7      2       yes
#
# [176 rows x 11 columns]
# /tmp/ipykernel_538/2085321507.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Firstname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
# /tmp/ipykernel_538/2085321507.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Firstname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
# /tmp/ipykernel_538/2085321507.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Lastname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
# /tmp/ipykernel_538/2085321507.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Lastname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)

# %%
# Vấn đề 7
#Thống kê thông tin dữ liệu thiếu trên từng biến Age và Weight
print("Số lượng giá trị thiếu:")
print(df[['Age', 'Weight']].isnull().sum())
#Xóa các dòng thiếu cả Age và Weight
df = df.drop(
    df[
        (df['Age'].isnull()) &
        (df['Weight'].isnull())
    ].index
)
#Thay thế giá trị thiếu của Age bằng giá trị trung bình
df['Weight'] = (
    df['Weight']
    .astype(str)
    .str.extract(r'(\d+\.?\d*)')[0]
    .astype(float)
)

df['Weight'].fillna(df['Weight'].mean(), inplace=True)
df[['Age', 'Weight']].isnull().sum()
# Out:
# Số lượng giá trị thiếu:
# Age       0
# Weight    0
# dtype: int64
# /tmp/ipykernel_538/587502430.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Weight'].fillna(df['Weight'].mean(), inplace=True)
# Age       0
# Weight    0
# dtype: int64

# %%
# Vấn đề 8: Một cột chứa quá nhiều thông tin cần được phân rã
#Chuyển dữ liệu từ Wide sang Long

# First, flatten the MultiIndex columns of df, which were created due to incorrect data loading.
# From the kernel state, the first level of the MultiIndex columns contains the intended names.
if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)

# Now, ensure 'Id' (capitalized) is used, as 'id' (lowercase) does not exist.
df_long = df.melt(
    id_vars=['Id'], # Changed from 'id' to 'Id'
    var_name='Code',
    value_name='BloodPressure'
)
#Tách giới tính
df_long['Gender'] = df_long['Code'].str[0]
#Tách nhóm tuổi
df_long['AgeGroup'] = df_long['Code'].str[1:]
#Chuyển ký hiệu giới tính thành tên
df_long['Gender'] = df_long['Gender'].replace({
    'm': 'Male',
    'f': 'Female'
})
print(df_long.head())
# Out:
#      Id Code BloodPressure Gender AgeGroup
# 0  chol  Age       restecg      A       ge
# 1   233  Age             2      A       ge
# 2   286  Age             2      A       ge
# 3   229  Age             2      A       ge
# 4   250  Age             0      A       ge
